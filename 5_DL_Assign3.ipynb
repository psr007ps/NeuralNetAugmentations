# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
class MixupGenerator():
    def __init__(self, X_train, y_train, batch_size=32, alpha=0.2, shuffle=True, datagen=None):
        self.X_train = X_train
        self.y_train = y_train
        self.batch_size = batch_size
        self.alpha = alpha
        self.shuffle = shuffle
        self.sample_num = len(X_train)
        self.datagen = datagen

    def __call__(self):
        while True:
            indexes = self.__get_exploration_order()
            itr_num = int(len(indexes) // (self.batch_size * 2))

            for i in range(itr_num):
                batch_ids = indexes[i * self.batch_size * 2:(i + 1) * self.batch_size * 2]
                X, y = self.__data_generation(batch_ids)

                yield X, y

    def __get_exploration_order(self):
        indexes = np.arange(self.sample_num)

        if self.shuffle:
            np.random.shuffle(indexes)

        return indexes

    def __data_generation(self, batch_ids):
        _, h, w, c = self.X_train.shape
        l = np.random.beta(self.alpha, self.alpha, self.batch_size)
        X_l = l.reshape(self.batch_size, 1, 1, 1)
        y_l = l.reshape(self.batch_size, 1)

        X1 = self.X_train[batch_ids[:self.batch_size]]
        X2 = self.X_train[batch_ids[self.batch_size:]]
        X = X1 * X_l + X2 * (1 - X_l)

        if self.datagen:
            for i in range(self.batch_size):
                X[i] = self.datagen.random_transform(X[i])
                X[i] = self.datagen.standardize(X[i])
                
        if isinstance(self.y_train, list):
            y = []

            for y_train_ in self.y_train:
                y1 = y_train_[batch_ids[:self.batch_size]]
                y2 = y_train_[batch_ids[self.batch_size:]]
                y.append(y1 * y_l + y2 * (1 - y_l))
        else:
            y1 = self.y_train[batch_ids[:self.batch_size]]
            y2 = self.y_train[batch_ids[self.batch_size:]]
            y = y1 * y_l + y2 * (1 - y_l)

        return X, y

# %%
import numpy as np


def translate(img, shift, direction):
    assert direction in ['right', 'left', 'down', 'up'], 'Directions should be top|up|left|right'
    img = img.copy()
    
    if direction == 'right':
        right_slice = img[:,:shift].shape
        img[:, shift:] = img[:, :-shift]
        img[:,:shift] = np.zeros(right_slice)
            
    if direction == 'left':
        left_slice = img[:, -shift:].shape
        img[:, :-shift] = img[:, shift:]
        img[:, -shift:] = np.zeros(left_slice)
    if direction == 'down':
        down_slice = img[:shift, :].shape
        img[shift:, :] = img[:-shift,:]
        img[:shift, :] = np.zeros(down_slice)
    if direction == 'up':
        upper_slice = img[-shift:,:].shape
        img[:-shift, :] = img[shift:, :]
        img[-shift:,:] = np.zeros(upper_slice)
    
    return img


def standard_augmentation():
  def augment(input_img, p=0.5, v_l=0, v_h=255):
    K = 4
    k1 = np.random.randint(-K, K)
    k2 = np.random.randint(-K, K)
    
    img_h, img_w, img_c = input_img.shape
    p_1 = np.random.rand()
    if k1!=0 and k2!=0:
      if k1>0:
        input_img = translate(input_img, shift=abs(k1), direction='up')
      else:
        input_img = translate(input_img, shift=abs(k1), direction='down')

      if k2>0:
        input_img = translate(input_img, shift=abs(k2), direction='right')
      else:
        input_img = translate(input_img, shift=abs(k2), direction='left')

    if p_1 > p:
      input_img = np.fliplr(input_img)

    #Cut-out augmentation
    
    p_2 = np.random.rand()

    if p_2 > p:
        return input_img
        
    w = 8
    mid_x = np.random.randint(0, img_w)
    mid_y = np.random.randint(0, img_h)
        
    c = np.random.uniform(v_l, v_h)
    input_img[mid_x - w : mid_x + w, mid_y - w : mid_y + w, :] = c
    return input_img

  return augment

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import CSVLogger
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 100
num_classes = 10
pixel_level = False

# Computed depth from supplied model parameter n
depth = 20

# Model name, depth and version
model_type = 'ResNet%dv' % (depth)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

#take 10000 samples out of 50000 for training
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, Y_test = train_test_split(x_train, y_train, stratify=y_train, test_size=0.8)

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

 

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v2(input_shape, depth, num_classes=10):
    
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model



model = resnet_v2(input_shape=input_shape, depth=depth)


model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])
model.summary()
print(model_type)

csv_logger = CSVLogger('training.log')


datagen = ImageDataGenerator(
        preprocessing_function=standard_augmentation())

datagen.fit(x_train)
'''
batches = datagen.flow(x_train, y_train, batch_size=batch_size)
x_batch, y_batch = next(batches)
for i in range (0,32):
    image = x_batch[i]
    plt.imshow(image)
    plt.show()
'''
training_generator = MixupGenerator(x_train, y_train, batch_size=batch_size, alpha=0.2, datagen = datagen)()
batches = training_generator
x_batch, y_batch = next(batches)
for i in range (0,32):
    image = x_batch[i]
    plt.imshow(image)
    plt.show()
# Fit the model on the batches generated by datagen.flow().
model.fit_generator(generator=training_generator,
                        steps_per_epoch=x_train.shape[0] // batch_size,
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1,
                        callbacks=[csv_logger]
                        )
             

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# x_train shape: (10000, 32, 32, 3)
# 10000 train samples
# 10000 test samples
# y_train shape: (10000, 1)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   4160        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  8320        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   8256        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  8320        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 128)  0           add_3[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    16512       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    33024       activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    32896       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 128)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 128)    512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 256)    33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 256)    0           add_5[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 256)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        flatten_1[0][0]
# ==================================================================================================
# Total params: 574,090
# Trainable params: 570,602
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 1/100
# 78/78 [==============================] - 19s 239ms/step - loss: 2.6581 - accuracy: 0.1512 - val_loss: 4.2781 - val_accuracy: 0.1000
# Epoch 2/100
# 78/78 [==============================] - 8s 96ms/step - loss: 2.4721 - accuracy: 0.2148 - val_loss: 3.7083 - val_accuracy: 0.1000
# Epoch 3/100
# 78/78 [==============================] - 7s 96ms/step - loss: 2.3701 - accuracy: 0.2441 - val_loss: 2.7140 - val_accuracy: 0.1244
# Epoch 4/100
# 78/78 [==============================] - 7s 96ms/step - loss: 2.2458 - accuracy: 0.2924 - val_loss: 3.2241 - val_accuracy: 0.1058
# Epoch 5/100
# 78/78 [==============================] - 7s 95ms/step - loss: 2.1213 - accuracy: 0.3311 - val_loss: 3.5775 - val_accuracy: 0.1083
# Epoch 6/100
# 78/78 [==============================] - 7s 95ms/step - loss: 2.0535 - accuracy: 0.3625 - val_loss: 2.3885 - val_accuracy: 0.2229
# Epoch 7/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.9650 - accuracy: 0.4008 - val_loss: 3.0532 - val_accuracy: 0.1161
# Epoch 8/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.8867 - accuracy: 0.4343 - val_loss: 2.8184 - val_accuracy: 0.2053
# Epoch 9/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.8475 - accuracy: 0.4545 - val_loss: 3.1397 - val_accuracy: 0.1469
# Epoch 10/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.7998 - accuracy: 0.4686 - val_loss: 2.1475 - val_accuracy: 0.3311
# Epoch 11/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.7481 - accuracy: 0.4984 - val_loss: 2.9747 - val_accuracy: 0.1923
# Epoch 12/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.6983 - accuracy: 0.5156 - val_loss: 2.6591 - val_accuracy: 0.2774
# Epoch 13/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.6701 - accuracy: 0.5245 - val_loss: 2.8404 - val_accuracy: 0.2351
# Epoch 14/100
# 78/78 [==============================] - 7s 94ms/step - loss: 1.6654 - accuracy: 0.5330 - val_loss: 3.0318 - val_accuracy: 0.2437
# Epoch 15/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.6515 - accuracy: 0.5337 - val_loss: 3.7230 - val_accuracy: 0.1170
# Epoch 16/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.6207 - accuracy: 0.5499 - val_loss: 2.0076 - val_accuracy: 0.4088
# Epoch 17/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.5754 - accuracy: 0.5599 - val_loss: 1.3442 - val_accuracy: 0.5943
# Epoch 18/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.5647 - accuracy: 0.5748 - val_loss: 1.9106 - val_accuracy: 0.4135
# Epoch 19/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.5521 - accuracy: 0.5775 - val_loss: 2.8825 - val_accuracy: 0.1869
# Epoch 20/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.5336 - accuracy: 0.5800 - val_loss: 3.7052 - val_accuracy: 0.1950
# Epoch 21/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.5152 - accuracy: 0.5925 - val_loss: 3.0234 - val_accuracy: 0.1615
# Epoch 22/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.5001 - accuracy: 0.6025 - val_loss: 5.8051 - val_accuracy: 0.1121
# Epoch 23/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.4817 - accuracy: 0.6064 - val_loss: 1.7919 - val_accuracy: 0.4524
# Epoch 24/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.4588 - accuracy: 0.6185 - val_loss: 1.5234 - val_accuracy: 0.5645
# Epoch 25/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.4438 - accuracy: 0.6240 - val_loss: 2.1116 - val_accuracy: 0.3952
# Epoch 26/100
# 78/78 [==============================] - 7s 94ms/step - loss: 1.4215 - accuracy: 0.6297 - val_loss: 2.6541 - val_accuracy: 0.2372
# Epoch 27/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.4030 - accuracy: 0.6440 - val_loss: 2.7065 - val_accuracy: 0.2880
# Epoch 28/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.3812 - accuracy: 0.6519 - val_loss: 2.0941 - val_accuracy: 0.4249
# Epoch 29/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.3779 - accuracy: 0.6547 - val_loss: 2.4484 - val_accuracy: 0.3051
# Epoch 30/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.3791 - accuracy: 0.6514 - val_loss: 1.8521 - val_accuracy: 0.4389
# Epoch 31/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.3462 - accuracy: 0.6604 - val_loss: 1.4036 - val_accuracy: 0.5726
# Epoch 32/100
# 78/78 [==============================] - 8s 97ms/step - loss: 1.3394 - accuracy: 0.6709 - val_loss: 4.3941 - val_accuracy: 0.1973
# Epoch 33/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.3261 - accuracy: 0.6806 - val_loss: 2.0454 - val_accuracy: 0.4249
# Epoch 34/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.2932 - accuracy: 0.6875 - val_loss: 2.5938 - val_accuracy: 0.3244
# Epoch 35/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.3030 - accuracy: 0.6903 - val_loss: 1.2194 - val_accuracy: 0.6456
# Epoch 36/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.2800 - accuracy: 0.6922 - val_loss: 2.2238 - val_accuracy: 0.3687
# Epoch 37/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.2587 - accuracy: 0.7003 - val_loss: 1.5975 - val_accuracy: 0.5258
# Epoch 38/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.2710 - accuracy: 0.7033 - val_loss: 2.1314 - val_accuracy: 0.3593
# Epoch 39/100
# 78/78 [==============================] - 8s 96ms/step - loss: 1.2582 - accuracy: 0.7074 - val_loss: 1.4212 - val_accuracy: 0.5731
# Epoch 40/100
# 78/78 [==============================] - 8s 96ms/step - loss: 1.2501 - accuracy: 0.7113 - val_loss: 1.9566 - val_accuracy: 0.4465
# Epoch 41/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.2277 - accuracy: 0.7157 - val_loss: 1.7314 - val_accuracy: 0.4921
# Epoch 42/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.2280 - accuracy: 0.7225 - val_loss: 2.0485 - val_accuracy: 0.4618
# Epoch 43/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.2045 - accuracy: 0.7264 - val_loss: 1.2472 - val_accuracy: 0.6361
# Epoch 44/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.2044 - accuracy: 0.7322 - val_loss: 1.9852 - val_accuracy: 0.4148
# Epoch 45/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.1982 - accuracy: 0.7342 - val_loss: 1.1082 - val_accuracy: 0.6829
# Epoch 46/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1899 - accuracy: 0.7300 - val_loss: 1.4842 - val_accuracy: 0.5536
# Epoch 47/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1780 - accuracy: 0.7391 - val_loss: 1.3183 - val_accuracy: 0.6242
# Epoch 48/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1834 - accuracy: 0.7441 - val_loss: 1.2885 - val_accuracy: 0.6272
# Epoch 49/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1611 - accuracy: 0.7481 - val_loss: 1.4545 - val_accuracy: 0.5667
# Epoch 50/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.1620 - accuracy: 0.7522 - val_loss: 1.3047 - val_accuracy: 0.6243
# Epoch 51/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1659 - accuracy: 0.7427 - val_loss: 1.9801 - val_accuracy: 0.4441
# Epoch 52/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1482 - accuracy: 0.7559 - val_loss: 1.7722 - val_accuracy: 0.4751
# Epoch 53/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1561 - accuracy: 0.7525 - val_loss: 1.4264 - val_accuracy: 0.5960
# Epoch 54/100
# 78/78 [==============================] - 7s 94ms/step - loss: 1.1582 - accuracy: 0.7558 - val_loss: 1.6478 - val_accuracy: 0.5278
# Epoch 55/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1447 - accuracy: 0.7548 - val_loss: 1.1263 - val_accuracy: 0.6863
# Epoch 56/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1233 - accuracy: 0.7661 - val_loss: 1.4146 - val_accuracy: 0.5841
# Epoch 57/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1141 - accuracy: 0.7689 - val_loss: 6.4166 - val_accuracy: 0.1569
# Epoch 58/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1146 - accuracy: 0.7633 - val_loss: 1.4665 - val_accuracy: 0.5521
# Epoch 59/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1066 - accuracy: 0.7714 - val_loss: 1.5750 - val_accuracy: 0.5316
# Epoch 60/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1154 - accuracy: 0.7698 - val_loss: 1.3744 - val_accuracy: 0.6115
# Epoch 61/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0853 - accuracy: 0.7773 - val_loss: 1.9998 - val_accuracy: 0.4485
# Epoch 62/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.1134 - accuracy: 0.7696 - val_loss: 1.2736 - val_accuracy: 0.6351
# Epoch 63/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0934 - accuracy: 0.7766 - val_loss: 2.0513 - val_accuracy: 0.4457
# Epoch 64/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0837 - accuracy: 0.7810 - val_loss: 2.0500 - val_accuracy: 0.4282
# Epoch 65/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0892 - accuracy: 0.7812 - val_loss: 1.6391 - val_accuracy: 0.5232
# Epoch 66/100
# 78/78 [==============================] - 7s 96ms/step - loss: 1.0851 - accuracy: 0.7809 - val_loss: 1.8452 - val_accuracy: 0.4954
# Epoch 67/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0870 - accuracy: 0.7792 - val_loss: 1.1039 - val_accuracy: 0.6914
# Epoch 68/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0758 - accuracy: 0.7820 - val_loss: 1.7560 - val_accuracy: 0.5202
# Epoch 69/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0647 - accuracy: 0.7929 - val_loss: 3.0236 - val_accuracy: 0.2860
# Epoch 70/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0503 - accuracy: 0.8008 - val_loss: 2.7113 - val_accuracy: 0.3093
# Epoch 71/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0493 - accuracy: 0.7941 - val_loss: 1.2873 - val_accuracy: 0.6264
# Epoch 72/100
# 78/78 [==============================] - 7s 94ms/step - loss: 1.0659 - accuracy: 0.7903 - val_loss: 1.7022 - val_accuracy: 0.5616
# Epoch 73/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0480 - accuracy: 0.8006 - val_loss: 1.2279 - val_accuracy: 0.6471
# Epoch 74/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0397 - accuracy: 0.7963 - val_loss: 1.1822 - val_accuracy: 0.6798
# Epoch 75/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0295 - accuracy: 0.8067 - val_loss: 1.2713 - val_accuracy: 0.6588
# Epoch 76/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0251 - accuracy: 0.8079 - val_loss: 2.8254 - val_accuracy: 0.3247
# Epoch 77/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0289 - accuracy: 0.7993 - val_loss: 1.8688 - val_accuracy: 0.4664
# Epoch 78/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0164 - accuracy: 0.8045 - val_loss: 2.4113 - val_accuracy: 0.4064
# Epoch 79/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0193 - accuracy: 0.8104 - val_loss: 1.4443 - val_accuracy: 0.5800
# Epoch 80/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0098 - accuracy: 0.8095 - val_loss: 2.0191 - val_accuracy: 0.4637
# Epoch 81/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0124 - accuracy: 0.8113 - val_loss: 1.5663 - val_accuracy: 0.5644
# Epoch 82/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0145 - accuracy: 0.8141 - val_loss: 1.2936 - val_accuracy: 0.6488
# Epoch 83/100
# 78/78 [==============================] - 7s 94ms/step - loss: 1.0008 - accuracy: 0.8180 - val_loss: 1.2621 - val_accuracy: 0.6480
# Epoch 84/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0024 - accuracy: 0.8136 - val_loss: 1.6415 - val_accuracy: 0.5607
# Epoch 85/100
# 78/78 [==============================] - 7s 95ms/step - loss: 1.0114 - accuracy: 0.8128 - val_loss: 1.6832 - val_accuracy: 0.4890
# Epoch 86/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9952 - accuracy: 0.8248 - val_loss: 1.3334 - val_accuracy: 0.6420
# Epoch 87/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9861 - accuracy: 0.8216 - val_loss: 1.5235 - val_accuracy: 0.5791
# Epoch 88/100
# 78/78 [==============================] - 7s 94ms/step - loss: 0.9849 - accuracy: 0.8229 - val_loss: 1.3820 - val_accuracy: 0.6193
# Epoch 89/100
# 78/78 [==============================] - 7s 94ms/step - loss: 0.9833 - accuracy: 0.8220 - val_loss: 2.2513 - val_accuracy: 0.4599
# Epoch 90/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9978 - accuracy: 0.8199 - val_loss: 1.1226 - val_accuracy: 0.6844
# Epoch 91/100
# 78/78 [==============================] - 7s 96ms/step - loss: 0.9736 - accuracy: 0.8292 - val_loss: 1.2541 - val_accuracy: 0.6483
# Epoch 92/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9776 - accuracy: 0.8254 - val_loss: 1.7165 - val_accuracy: 0.5481
# Epoch 93/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9739 - accuracy: 0.8253 - val_loss: 1.5617 - val_accuracy: 0.5893
# Epoch 94/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9876 - accuracy: 0.8236 - val_loss: 3.3811 - val_accuracy: 0.3548
# Epoch 95/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9705 - accuracy: 0.8310 - val_loss: 1.7890 - val_accuracy: 0.5522
# Epoch 96/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9603 - accuracy: 0.8326 - val_loss: 2.4153 - val_accuracy: 0.4978
# Epoch 97/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9583 - accuracy: 0.8397 - val_loss: 1.2696 - val_accuracy: 0.6642
# Epoch 98/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9630 - accuracy: 0.8340 - val_loss: 1.2833 - val_accuracy: 0.6601
# Epoch 99/100
# 78/78 [==============================] - 7s 94ms/step - loss: 0.9660 - accuracy: 0.8346 - val_loss: 2.0589 - val_accuracy: 0.4247
# Epoch 100/100
# 78/78 [==============================] - 7s 95ms/step - loss: 0.9480 - accuracy: 0.8401 - val_loss: 1.8154 - val_accuracy: 0.4897
# 10000/10000 [==============================] - 3s 335us/step
# Test loss: 1.8153671907424926
# Test accuracy: 0.48969998955726624
